# %%
from nac_plot import get_data
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
stats = get_data()

# %%
len(stats)
# Out:
# 24

# %%
#plt.plot(entrop)
stats.keys()
# Out:
# dict_keys(['Cell2/Branch1', 'Cell6/Branch2', 'Cell1/Branch2', 'Cell7/Branch3', 'Cell2/Branch0', 'Cell7/Branch0', 'Cell4/Branch1', 'Cell3/Branch1', 'Cell3/Branch3', 'Cell3/Branch2', 'Cell4/Branch2', 'Cell6/Branch3', 'Cell2/Branch3', 'Cell1/Branch1', 'Cell6/Branch1', 'Cell1/Branch3', 'Cell4/Branch0', 'Cell7/Branch2', 'Cell1/Branch0', 'Cell6/Branch0', 'Cell7/Branch1', 'Cell4/Branch3', 'Cell2/Branch2', 'Cell3/Branch0'])

# %%
plt.plot(stats['Cell1/Branch0'], label='Cell1/Branch0')
plt.plot(stats['Cell1/Branch1'], label='Cell1/Branch1')
plt.plot(stats['Cell1/Branch2'], label='Cell1/Branch2')
plt.plot(stats['Cell1/Branch3'], label='Cell1/Branch3')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.plot(stats['Cell2/Branch0'], label='Cell2/Branch0')
plt.plot(stats['Cell2/Branch1'], label='Cell2/Branch1')
plt.plot(stats['Cell2/Branch2'], label='Cell2/Branch2')
plt.plot(stats['Cell2/Branch3'], label='Cell2/Branch3')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.plot(stats['Cell3/Branch0'], label='Cell3/Branch0')
plt.plot(stats['Cell3/Branch1'], label='Cell3/Branch1')
plt.plot(stats['Cell3/Branch2'], label='Cell3/Branch2')
plt.plot(stats['Cell3/Branch3'], label='Cell3/Branch3')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.plot(stats['Cell4/Branch0'], label='Cell4/Branch0')
plt.plot(stats['Cell4/Branch1'], label='Cell4/Branch1')
plt.plot(stats['Cell4/Branch2'], label='Cell4/Branch2')
plt.plot(stats['Cell4/Branch3'], label='Cell4/Branch3')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.plot(stats['Cell6/Branch0'], label='Cell6/Branch0')
plt.plot(stats['Cell6/Branch1'], label='Cell6/Branch1')
plt.plot(stats['Cell6/Branch2'], label='Cell6/Branch2')
plt.plot(stats['Cell6/Branch3'], label='Cell6/Branch3')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.plot(stats['Cell7/Branch0'], label='Cell7/Branch0')
plt.plot(stats['Cell7/Branch1'], label='Cell7/Branch1')
plt.plot(stats['Cell7/Branch2'], label='Cell7/Branch2')
plt.plot(stats['Cell7/Branch3'], label='Cell7/Branch3')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
